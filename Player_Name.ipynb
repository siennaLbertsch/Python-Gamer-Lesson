# %% [markdown]
# <a href="https://colab.research.google.com/github/siennaLbertsch/Python-Gamer-Lesson/blob/main/Player_Name.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
player_name = input("What is your gamer name? ")
print("Welcome to the game, " + player_name)
