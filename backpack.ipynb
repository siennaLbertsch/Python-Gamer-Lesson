# %% [markdown]
# <a href="https://colab.research.google.com/github/siennaLbertsch/Python-Gamer-Lesson/blob/main/backpack.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
backpack = "Diamond Sword, Magic Carpet"
print(backpack)
# Out:
# Diamond Sword, Magic Carpet
